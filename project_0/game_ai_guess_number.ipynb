# %%
import game_ai_guess_number

# %% [markdown]
# # Игра "Компьютер угадывает число"

# %%
from game_ai_guess_number import random_predict, score_game

# %% [markdown]
# ## Угадываем случайно в диапазоне от 1 до 100

# %%
# стандартный вызов функции угадывания случайного числа
print(f'Количество попыток: {random_predict()}')
# выводим метрику качества
print(f'Алгоритм угадывает число в среднем за: {score_game(random_predict)} попыток')
# Out:
# загаданное число=18 mid=50 min=1 max=100
# загаданное число=18 mid=26 min=1 max=50
# загаданное число=18 mid=14 min=1 max=26
# загаданное число=18 mid=20 min=14 max=26
# загаданное число=18 mid=17 min=14 max=20
# загаданное число=18 mid=18 min=17 max=20
# Количество попыток: 6
# загаданное число=72 mid=50 min=1 max=100
# загаданное число=72 mid=75 min=50 max=100
# загаданное число=72 mid=62 min=50 max=75
# загаданное число=72 mid=68 min=62 max=75
# загаданное число=72 mid=72 min=68 max=75
# загаданное число=74 mid=50 min=1 max=100
# загаданное число=74 mid=75 min=50 max=100
# загаданное число=74 mid=62 min=50 max=75
# загаданное число=74 mid=68 min=62 max=75
# загаданное число=74 mid=72 min=68 max=75
# загаданное число=74 mid=74 min=72 max=75
# загаданное число=21 mid=50 min=1 max=100
# загаданное число=21 mid=26 min=1 max=50
# загаданное число=21 mid=14 min=1 max=26
# загаданное число=21 mid=20 min=14 max=26
# загаданное число=21 mid=23 min=20 max=26
# ...
