# %%
import game_ai_guess_number

# %% [markdown]
# # Игра "Компьютер угадывает число"

# %%
from game_ai_guess_number import random_predict, score_game

# %% [markdown]
# ## Угадываем случайно в диапазоне от 1 до 100

# %%
# стандартный вызов функции угадывания случайного числа
print(f'Количество попыток: {random_predict()}')
# выводим метрику качества
print(f'Алгоритм угадывает число в среднем за: {score_game(random_predict)} попыток')
# Out:
# Загаданное число=18 mid=50 min_val=1 max_val=100
# Загаданное число=18 mid=26 min_val=1 max_val=50
# Загаданное число=18 mid=14 min_val=1 max_val=26
# Загаданное число=18 mid=20 min_val=14 max_val=26
# Загаданное число=18 mid=17 min_val=14 max_val=20
# Загаданное число=18 mid=18 min_val=17 max_val=20
# Количество попыток: 6
# Загаданное число=67 mid=50 min_val=1 max_val=100
# Загаданное число=67 mid=75 min_val=50 max_val=100
# Загаданное число=67 mid=62 min_val=50 max_val=75
# Загаданное число=67 mid=68 min_val=62 max_val=75
# Загаданное число=67 mid=65 min_val=62 max_val=68
# Загаданное число=67 mid=66 min_val=65 max_val=68
# Загаданное число=67 mid=67 min_val=66 max_val=68
# Загаданное число=78 mid=50 min_val=1 max_val=100
# Загаданное число=78 mid=75 min_val=50 max_val=100
# Загаданное число=78 mid=88 min_val=75 max_val=100
# Загаданное число=78 mid=82 min_val=75 max_val=88
# Загаданное число=78 mid=78 min_val=75 max_val=82
# Загаданное число=42 mid=50 min_val=1 max_val=100
# Загаданное число=42 mid=26 min_val=1 max_val=50
# Загаданное число=42 mid=38 min_val=26 max_val=50
# Загаданное число=42 mid=44 min_val=38 max_val=50
# Загаданное число=42 mid=41 min_val=38 max_val=44
# Загаданное число=42 mid=42 min_val=41 max_val=44
# Загаданное число=27 mid=50 min_val=1 max_val=100
# Загаданное число=27 mid=26 min_val=1 max_val=50
# Загаданное число=27 mid=38 min_val=26 max_val=50
# Загаданное число=27 mid=32 min_val=26 max_val=38
# Загаданное число=27 mid=29 min_val=26 max_val=32
# Загаданное число=27 mid=28 min_val=26 max_val=29
# Загаданное число=27 mid=27 min_val=26 max_val=28
# Загаданное число=60 mid=50 min_val=1 max_val=100
# Загаданное число=60 mid=75 min_val=50 max_val=100
# Загаданное число=60 mid=62 min_val=50 max_val=75
# Загаданное число=60 mid=56 min_val=50 max_val=62
# Загаданное число=60 mid=59 min_val=56 max_val=62
# Загаданное число=60 mid=60 min_val=59 max_val=62
# Загаданное число=65 mid=50 min_val=1 max_val=100
# Загаданное число=65 mid=75 min_val=50 max_val=100
# Загаданное число=65 mid=62 min_val=50 max_val=75
# Загаданное число=65 mid=68 min_val=62 max_val=75
# Загаданное число=65 mid=65 min_val=62 max_val=68
# Загаданное число=83 mid=50 min_val=1 max_val=100
# Загаданное число=83 mid=75 min_val=50 max_val=100
# Загаданное число=83 mid=88 min_val=75 max_val=100
# Загаданное число=83 mid=82 min_val=75 max_val=88
# Загаданное число=83 mid=85 min_val=82 max_val=88
# Загаданное число=83 mid=84 min_val=82 max_val=85
# Загаданное число=83 mid=83 min_val=82 max_val=84
# Загаданное число=59 mid=50 min_val=1 max_val=100
# Загаданное число=59 mid=75 min_val=50 max_val=100
# Загаданное число=59 mid=62 min_val=50 max_val=75
# Загаданное число=59 mid=56 min_val=50 max_val=62
# Загаданное число=59 mid=59 min_val=56 max_val=62
# Загаданное число=81 mid=50 min_val=1 max_val=100
# Загаданное число=81 mid=75 min_val=50 max_val=100
# Загаданное число=81 mid=88 min_val=75 max_val=100
# Загаданное число=81 mid=82 min_val=75 max_val=88
# Загаданное число=81 mid=78 min_val=75 max_val=82
# Загаданное число=81 mid=80 min_val=78 max_val=82
# Загаданное число=81 mid=81 min_val=80 max_val=82
# Загаданное число=77 mid=50 min_val=1 max_val=100
# Загаданное число=77 mid=75 min_val=50 max_val=100
# Загаданное число=77 mid=88 min_val=75 max_val=100
# Загаданное число=77 mid=82 min_val=75 max_val=88
# Загаданное число=77 mid=78 min_val=75 max_val=82
# Загаданное число=77 mid=76 min_val=75 max_val=78
# Загаданное число=77 mid=77 min_val=76 max_val=78
# Загаданное число=78 mid=50 min_val=1 max_val=100
# Загаданное число=78 mid=75 min_val=50 max_val=100
# Загаданное число=78 mid=88 min_val=75 max_val=100
# Загаданное число=78 mid=82 min_val=75 max_val=88
# Загаданное число=78 mid=78 min_val=75 max_val=82
# Загаданное число=22 mid=50 min_val=1 max_val=100
# Загаданное число=22 mid=26 min_val=1 max_val=50
# Загаданное число=22 mid=14 min_val=1 max_val=26
# Загаданное число=22 mid=20 min_val=14 max_val=26
# Загаданное число=22 mid=23 min_val=20 max_val=26
# Загаданное число=22 mid=22 min_val=20 max_val=23
# Загаданное число=76 mid=50 min_val=1 max_val=100
# Загаданное число=76 mid=75 min_val=50 max_val=100
# Загаданное число=76 mid=88 min_val=75 max_val=100
# Загаданное число=76 mid=82 min_val=75 max_val=88
# Загаданное число=76 mid=78 min_val=75 max_val=82
# Загаданное число=76 mid=76 min_val=75 max_val=78
# Загаданное число=90 mid=50 min_val=1 max_val=100
# Загаданное число=90 mid=75 min_val=50 max_val=100
# Загаданное число=90 mid=88 min_val=75 max_val=100
# Загаданное число=90 mid=94 min_val=88 max_val=100
# Загаданное число=90 mid=91 min_val=88 max_val=94
# Загаданное число=90 mid=90 min_val=88 max_val=91
# Загаданное число=67 mid=50 min_val=1 max_val=100
# Загаданное число=67 mid=75 min_val=50 max_val=100
# Загаданное число=67 mid=62 min_val=50 max_val=75
# Загаданное число=67 mid=68 min_val=62 max_val=75
# Загаданное число=67 mid=65 min_val=62 max_val=68
# Загаданное число=67 mid=66 min_val=65 max_val=68
# Загаданное число=67 mid=67 min_val=66 max_val=68
# Загаданное число=1 mid=49 min_val=1 max_val=100
# Загаданное число=1 mid=24 min_val=1 max_val=49
# Загаданное число=1 mid=11 min_val=1 max_val=24
# Загаданное число=1 mid=5 min_val=1 max_val=11
# Загаданное число=1 mid=2 min_val=1 max_val=5
# Загаданное число=1 mid=1 min_val=1 max_val=2
# Загаданное число=10 mid=50 min_val=1 max_val=100
# Загаданное число=10 mid=26 min_val=1 max_val=50
# Загаданное число=10 mid=14 min_val=1 max_val=26
# Загаданное число=10 mid=8 min_val=1 max_val=14
# Загаданное число=10 mid=11 min_val=8 max_val=14
# Загаданное число=10 mid=10 min_val=8 max_val=11
# Загаданное число=33 mid=50 min_val=1 max_val=100
# Загаданное число=33 mid=26 min_val=1 max_val=50
# Загаданное число=33 mid=38 min_val=26 max_val=50
# Загаданное число=33 mid=32 min_val=26 max_val=38
# Загаданное число=33 mid=35 min_val=32 max_val=38
# Загаданное число=33 mid=34 min_val=32 max_val=35
# Загаданное число=33 mid=33 min_val=32 max_val=34
# Загаданное число=36 mid=50 min_val=1 max_val=100
# Загаданное число=36 mid=26 min_val=1 max_val=50
# Загаданное число=36 mid=38 min_val=26 max_val=50
# Загаданное число=36 mid=32 min_val=26 max_val=38
# Загаданное число=36 mid=35 min_val=32 max_val=38
# Загаданное число=36 mid=36 min_val=35 max_val=38
# Загаданное число=65 mid=50 min_val=1 max_val=100
# Загаданное число=65 mid=75 min_val=50 max_val=100
# Загаданное число=65 mid=62 min_val=50 max_val=75
# Загаданное число=65 mid=68 min_val=62 max_val=75
# Загаданное число=65 mid=65 min_val=62 max_val=68
# Загаданное число=58 mid=50 min_val=1 max_val=100
# Загаданное число=58 mid=75 min_val=50 max_val=100
# Загаданное число=58 mid=62 min_val=50 max_val=75
# Загаданное число=58 mid=56 min_val=50 max_val=62
# Загаданное число=58 mid=59 min_val=56 max_val=62
# Загаданное число=58 mid=58 min_val=56 max_val=59
# Загаданное число=62 mid=50 min_val=1 max_val=100
# Загаданное число=62 mid=75 min_val=50 max_val=100
# Загаданное число=62 mid=62 min_val=50 max_val=75
# Загаданное число=79 mid=50 min_val=1 max_val=100
# Загаданное число=79 mid=75 min_val=50 max_val=100
# Загаданное число=79 mid=88 min_val=75 max_val=100
# Загаданное число=79 mid=82 min_val=75 max_val=88
# Загаданное число=79 mid=78 min_val=75 max_val=82
# Загаданное число=79 mid=80 min_val=78 max_val=82
# Загаданное число=79 mid=79 min_val=78 max_val=80
# Загаданное число=10 mid=50 min_val=1 max_val=100
# Загаданное число=10 mid=26 min_val=1 max_val=50
# Загаданное число=10 mid=14 min_val=1 max_val=26
# Загаданное число=10 mid=8 min_val=1 max_val=14
# Загаданное число=10 mid=11 min_val=8 max_val=14
# Загаданное число=10 mid=10 min_val=8 max_val=11
# Загаданное число=97 mid=50 min_val=1 max_val=100
# Загаданное число=97 mid=75 min_val=50 max_val=100
# Загаданное число=97 mid=88 min_val=75 max_val=100
# Загаданное число=97 mid=94 min_val=88 max_val=100
# Загаданное число=97 mid=97 min_val=94 max_val=100
# Загаданное число=51 mid=50 min_val=1 max_val=100
# Загаданное число=51 mid=75 min_val=50 max_val=100
# Загаданное число=51 mid=62 min_val=50 max_val=75
# Загаданное число=51 mid=56 min_val=50 max_val=62
# Загаданное число=51 mid=53 min_val=50 max_val=56
# Загаданное число=51 mid=52 min_val=50 max_val=53
# Загаданное число=51 mid=51 min_val=50 max_val=52
# Загаданное число=94 mid=50 min_val=1 max_val=100
# Загаданное число=94 mid=75 min_val=50 max_val=100
# Загаданное число=94 mid=88 min_val=75 max_val=100
# Загаданное число=94 mid=94 min_val=88 max_val=100
# Загаданное число=87 mid=50 min_val=1 max_val=100
# Загаданное число=87 mid=75 min_val=50 max_val=100
# Загаданное число=87 mid=88 min_val=75 max_val=100
# Загаданное число=87 mid=82 min_val=75 max_val=88
# Загаданное число=87 mid=85 min_val=82 max_val=88
# Загаданное число=87 mid=86 min_val=85 max_val=88
# Загаданное число=87 mid=87 min_val=86 max_val=88
# Загаданное число=2 mid=50 min_val=1 max_val=100
# Загаданное число=2 mid=26 min_val=1 max_val=50
# Загаданное число=2 mid=14 min_val=1 max_val=26
# Загаданное число=2 mid=8 min_val=1 max_val=14
# Загаданное число=2 mid=4 min_val=1 max_val=8
# Загаданное число=2 mid=2 min_val=1 max_val=4
# Загаданное число=59 mid=50 min_val=1 max_val=100
# Загаданное число=59 mid=75 min_val=50 max_val=100
# Загаданное число=59 mid=62 min_val=50 max_val=75
# Загаданное число=59 mid=56 min_val=50 max_val=62
# Загаданное число=59 mid=59 min_val=56 max_val=62
# Загаданное число=34 mid=50 min_val=1 max_val=100
# Загаданное число=34 mid=26 min_val=1 max_val=50
# Загаданное число=34 mid=38 min_val=26 max_val=50
# Загаданное число=34 mid=32 min_val=26 max_val=38
# Загаданное число=34 mid=35 min_val=32 max_val=38
# Загаданное число=34 mid=34 min_val=32 max_val=35
# Загаданное число=82 mid=50 min_val=1 max_val=100
# Загаданное число=82 mid=75 min_val=50 max_val=100
# Загаданное число=82 mid=88 min_val=75 max_val=100
# Загаданное число=82 mid=82 min_val=75 max_val=88
# Загаданное число=86 mid=50 min_val=1 max_val=100
# Загаданное число=86 mid=75 min_val=50 max_val=100
# Загаданное число=86 mid=88 min_val=75 max_val=100
# Загаданное число=86 mid=82 min_val=75 max_val=88
# Загаданное число=86 mid=85 min_val=82 max_val=88
# Загаданное число=86 mid=86 min_val=85 max_val=88
# Загаданное число=15 mid=50 min_val=1 max_val=100
# Загаданное число=15 mid=26 min_val=1 max_val=50
# Загаданное число=15 mid=14 min_val=1 max_val=26
# Загаданное число=15 mid=20 min_val=14 max_val=26
# Загаданное число=15 mid=17 min_val=14 max_val=20
# Загаданное число=15 mid=16 min_val=14 max_val=17
# Загаданное число=15 mid=15 min_val=14 max_val=16
# Загаданное число=93 mid=50 min_val=1 max_val=100
# Загаданное число=93 mid=75 min_val=50 max_val=100
# Загаданное число=93 mid=88 min_val=75 max_val=100
# Загаданное число=93 mid=94 min_val=88 max_val=100
# Загаданное число=93 mid=91 min_val=88 max_val=94
# Загаданное число=93 mid=92 min_val=91 max_val=94
# Загаданное число=93 mid=93 min_val=92 max_val=94
# Загаданное число=25 mid=50 min_val=1 max_val=100
# Загаданное число=25 mid=26 min_val=1 max_val=50
# Загаданное число=25 mid=14 min_val=1 max_val=26
# Загаданное число=25 mid=20 min_val=14 max_val=26
# Загаданное число=25 mid=23 min_val=20 max_val=26
# Загаданное число=25 mid=24 min_val=23 max_val=26
# Загаданное число=25 mid=25 min_val=24 max_val=26
# Загаданное число=1 mid=49 min_val=1 max_val=100
# Загаданное число=1 mid=24 min_val=1 max_val=49
# Загаданное число=1 mid=11 min_val=1 max_val=24
# Загаданное число=1 mid=5 min_val=1 max_val=11
# Загаданное число=1 mid=2 min_val=1 max_val=5
# Загаданное число=1 mid=1 min_val=1 max_val=2
# Загаданное число=89 mid=50 min_val=1 max_val=100
# Загаданное число=89 mid=75 min_val=50 max_val=100
# Загаданное число=89 mid=88 min_val=75 max_val=100
# Загаданное число=89 mid=94 min_val=88 max_val=100
# Загаданное число=89 mid=91 min_val=88 max_val=94
# Загаданное число=89 mid=90 min_val=88 max_val=91
# Загаданное число=89 mid=89 min_val=88 max_val=90
# Загаданное число=98 mid=50 min_val=1 max_val=100
# Загаданное число=98 mid=75 min_val=50 max_val=100
# Загаданное число=98 mid=88 min_val=75 max_val=100
# Загаданное число=98 mid=94 min_val=88 max_val=100
# Загаданное число=98 mid=97 min_val=94 max_val=100
# Загаданное число=98 mid=98 min_val=97 max_val=100
# Загаданное число=36 mid=50 min_val=1 max_val=100
# Загаданное число=36 mid=26 min_val=1 max_val=50
# Загаданное число=36 mid=38 min_val=26 max_val=50
# Загаданное число=36 mid=32 min_val=26 max_val=38
# Загаданное число=36 mid=35 min_val=32 max_val=38
# Загаданное число=36 mid=36 min_val=35 max_val=38
# Загаданное число=79 mid=50 min_val=1 max_val=100
# Загаданное число=79 mid=75 min_val=50 max_val=100
# Загаданное число=79 mid=88 min_val=75 max_val=100
# Загаданное число=79 mid=82 min_val=75 max_val=88
# Загаданное число=79 mid=78 min_val=75 max_val=82
# Загаданное число=79 mid=80 min_val=78 max_val=82
# Загаданное число=79 mid=79 min_val=78 max_val=80
# Загаданное число=54 mid=50 min_val=1 max_val=100
# Загаданное число=54 mid=75 min_val=50 max_val=100
# Загаданное число=54 mid=62 min_val=50 max_val=75
# Загаданное число=54 mid=56 min_val=50 max_val=62
# Загаданное число=54 mid=53 min_val=50 max_val=56
# Загаданное число=54 mid=54 min_val=53 max_val=56
# Загаданное число=77 mid=50 min_val=1 max_val=100
# Загаданное число=77 mid=75 min_val=50 max_val=100
# Загаданное число=77 mid=88 min_val=75 max_val=100
# Загаданное число=77 mid=82 min_val=75 max_val=88
# Загаданное число=77 mid=78 min_val=75 max_val=82
# Загаданное число=77 mid=76 min_val=75 max_val=78
# Загаданное число=77 mid=77 min_val=76 max_val=78
# Загаданное число=76 mid=50 min_val=1 max_val=100
# Загаданное число=76 mid=75 min_val=50 max_val=100
# Загаданное число=76 mid=88 min_val=75 max_val=100
# Загаданное число=76 mid=82 min_val=75 max_val=88
# Загаданное число=76 mid=78 min_val=75 max_val=82
# Загаданное число=76 mid=76 min_val=75 max_val=78
# Загаданное число=35 mid=50 min_val=1 max_val=100
# Загаданное число=35 mid=26 min_val=1 max_val=50
# Загаданное число=35 mid=38 min_val=26 max_val=50
# Загаданное число=35 mid=32 min_val=26 max_val=38
# Загаданное число=35 mid=35 min_val=32 max_val=38
# Загаданное число=44 mid=50 min_val=1 max_val=100
# Загаданное число=44 mid=26 min_val=1 max_val=50
# Загаданное число=44 mid=38 min_val=26 max_val=50
# Загаданное число=44 mid=44 min_val=38 max_val=50
# Загаданное число=93 mid=50 min_val=1 max_val=100
# Загаданное число=93 mid=75 min_val=50 max_val=100
# Загаданное число=93 mid=88 min_val=75 max_val=100
# Загаданное число=93 mid=94 min_val=88 max_val=100
# Загаданное число=93 mid=91 min_val=88 max_val=94
# Загаданное число=93 mid=92 min_val=91 max_val=94
# Загаданное число=93 mid=93 min_val=92 max_val=94
# Загаданное число=89 mid=50 min_val=1 max_val=100
# Загаданное число=89 mid=75 min_val=50 max_val=100
# Загаданное число=89 mid=88 min_val=75 max_val=100
# Загаданное число=89 mid=94 min_val=88 max_val=100
# Загаданное число=89 mid=91 min_val=88 max_val=94
# Загаданное число=89 mid=90 min_val=88 max_val=91
# Загаданное число=89 mid=89 min_val=88 max_val=90
# Загаданное число=7 mid=50 min_val=1 max_val=100
# Загаданное число=7 mid=26 min_val=1 max_val=50
# Загаданное число=7 mid=14 min_val=1 max_val=26
# Загаданное число=7 mid=8 min_val=1 max_val=14
# Загаданное число=7 mid=4 min_val=1 max_val=8
# Загаданное число=7 mid=6 min_val=4 max_val=8
# Загаданное число=7 mid=7 min_val=6 max_val=8
# Загаданное число=48 mid=50 min_val=1 max_val=100
# Загаданное число=48 mid=26 min_val=1 max_val=50
# Загаданное число=48 mid=38 min_val=26 max_val=50
# Загаданное число=48 mid=44 min_val=38 max_val=50
# Загаданное число=48 mid=47 min_val=44 max_val=50
# Загаданное число=48 mid=48 min_val=47 max_val=50
# Загаданное число=29 mid=50 min_val=1 max_val=100
# Загаданное число=29 mid=26 min_val=1 max_val=50
# Загаданное число=29 mid=38 min_val=26 max_val=50
# Загаданное число=29 mid=32 min_val=26 max_val=38
# Загаданное число=29 mid=29 min_val=26 max_val=32
# Загаданное число=14 mid=50 min_val=1 max_val=100
# Загаданное число=14 mid=26 min_val=1 max_val=50
# Загаданное число=14 mid=14 min_val=1 max_val=26
# Загаданное число=61 mid=50 min_val=1 max_val=100
# Загаданное число=61 mid=75 min_val=50 max_val=100
# Загаданное число=61 mid=62 min_val=50 max_val=75
# Загаданное число=61 mid=56 min_val=50 max_val=62
# Загаданное число=61 mid=59 min_val=56 max_val=62
# Загаданное число=61 mid=60 min_val=59 max_val=62
# Загаданное число=61 mid=61 min_val=60 max_val=62
# Загаданное число=1 mid=49 min_val=1 max_val=100
# Загаданное число=1 mid=24 min_val=1 max_val=49
# Загаданное число=1 mid=11 min_val=1 max_val=24
# Загаданное число=1 mid=5 min_val=1 max_val=11
# Загаданное число=1 mid=2 min_val=1 max_val=5
# Загаданное число=1 mid=1 min_val=1 max_val=2
# Загаданное число=86 mid=50 min_val=1 max_val=100
# Загаданное число=86 mid=75 min_val=50 max_val=100
# Загаданное число=86 mid=88 min_val=75 max_val=100
# Загаданное число=86 mid=82 min_val=75 max_val=88
# Загаданное число=86 mid=85 min_val=82 max_val=88
# Загаданное число=86 mid=86 min_val=85 max_val=88
# Загаданное число=80 mid=50 min_val=1 max_val=100
# Загаданное число=80 mid=75 min_val=50 max_val=100
# Загаданное число=80 mid=88 min_val=75 max_val=100
# Загаданное число=80 mid=82 min_val=75 max_val=88
# Загаданное число=80 mid=78 min_val=75 max_val=82
# Загаданное число=80 mid=80 min_val=78 max_val=82
# Загаданное число=30 mid=50 min_val=1 max_val=100
# Загаданное число=30 mid=26 min_val=1 max_val=50
# Загаданное число=30 mid=38 min_val=26 max_val=50
# Загаданное число=30 mid=32 min_val=26 max_val=38
# Загаданное число=30 mid=29 min_val=26 max_val=32
# Загаданное число=30 mid=30 min_val=29 max_val=32
# Загаданное число=73 mid=50 min_val=1 max_val=100
# Загаданное число=73 mid=75 min_val=50 max_val=100
# Загаданное число=73 mid=62 min_val=50 max_val=75
# Загаданное число=73 mid=68 min_val=62 max_val=75
# Загаданное число=73 mid=72 min_val=68 max_val=75
# Загаданное число=73 mid=74 min_val=72 max_val=75
# Загаданное число=73 mid=73 min_val=72 max_val=74
# Загаданное число=93 mid=50 min_val=1 max_val=100
# Загаданное число=93 mid=75 min_val=50 max_val=100
# Загаданное число=93 mid=88 min_val=75 max_val=100
# Загаданное число=93 mid=94 min_val=88 max_val=100
# Загаданное число=93 mid=91 min_val=88 max_val=94
# Загаданное число=93 mid=92 min_val=91 max_val=94
# Загаданное число=93 mid=93 min_val=92 max_val=94
# Загаданное число=19 mid=50 min_val=1 max_val=100
# Загаданное число=19 mid=26 min_val=1 max_val=50
# Загаданное число=19 mid=14 min_val=1 max_val=26
# Загаданное число=19 mid=20 min_val=14 max_val=26
# Загаданное число=19 mid=17 min_val=14 max_val=20
# Загаданное число=19 mid=18 min_val=17 max_val=20
# Загаданное число=19 mid=19 min_val=18 max_val=20
# Загаданное число=61 mid=50 min_val=1 max_val=100
# Загаданное число=61 mid=75 min_val=50 max_val=100
# Загаданное число=61 mid=62 min_val=50 max_val=75
# Загаданное число=61 mid=56 min_val=50 max_val=62
# Загаданное число=61 mid=59 min_val=56 max_val=62
# Загаданное число=61 mid=60 min_val=59 max_val=62
# Загаданное число=61 mid=61 min_val=60 max_val=62
# Загаданное число=5 mid=50 min_val=1 max_val=100
# Загаданное число=5 mid=26 min_val=1 max_val=50
# Загаданное число=5 mid=14 min_val=1 max_val=26
# Загаданное число=5 mid=8 min_val=1 max_val=14
# Загаданное число=5 mid=4 min_val=1 max_val=8
# Загаданное число=5 mid=6 min_val=4 max_val=8
# Загаданное число=5 mid=5 min_val=4 max_val=6
# Загаданное число=70 mid=50 min_val=1 max_val=100
# Загаданное число=70 mid=75 min_val=50 max_val=100
# Загаданное число=70 mid=62 min_val=50 max_val=75
# Загаданное число=70 mid=68 min_val=62 max_val=75
# Загаданное число=70 mid=72 min_val=68 max_val=75
# Загаданное число=70 mid=70 min_val=68 max_val=72
# Загаданное число=75 mid=50 min_val=1 max_val=100
# Загаданное число=75 mid=75 min_val=50 max_val=100
# Загаданное число=25 mid=50 min_val=1 max_val=100
# Загаданное число=25 mid=26 min_val=1 max_val=50
# Загаданное число=25 mid=14 min_val=1 max_val=26
# Загаданное число=25 mid=20 min_val=14 max_val=26
# Загаданное число=25 mid=23 min_val=20 max_val=26
# Загаданное число=25 mid=24 min_val=23 max_val=26
# Загаданное число=25 mid=25 min_val=24 max_val=26
# Загаданное число=29 mid=50 min_val=1 max_val=100
# Загаданное число=29 mid=26 min_val=1 max_val=50
# Загаданное число=29 mid=38 min_val=26 max_val=50
# Загаданное число=29 mid=32 min_val=26 max_val=38
# Загаданное число=29 mid=29 min_val=26 max_val=32
# Загаданное число=92 mid=50 min_val=1 max_val=100
# Загаданное число=92 mid=75 min_val=50 max_val=100
# Загаданное число=92 mid=88 min_val=75 max_val=100
# Загаданное число=92 mid=94 min_val=88 max_val=100
# Загаданное число=92 mid=91 min_val=88 max_val=94
# Загаданное число=92 mid=92 min_val=91 max_val=94
# Загаданное число=36 mid=50 min_val=1 max_val=100
# Загаданное число=36 mid=26 min_val=1 max_val=50
# Загаданное число=36 mid=38 min_val=26 max_val=50
# Загаданное число=36 mid=32 min_val=26 max_val=38
# Загаданное число=36 mid=35 min_val=32 max_val=38
# Загаданное число=36 mid=36 min_val=35 max_val=38
# Загаданное число=78 mid=50 min_val=1 max_val=100
# Загаданное число=78 mid=75 min_val=50 max_val=100
# Загаданное число=78 mid=88 min_val=75 max_val=100
# Загаданное число=78 mid=82 min_val=75 max_val=88
# Загаданное число=78 mid=78 min_val=75 max_val=82
# Загаданное число=82 mid=50 min_val=1 max_val=100
# Загаданное число=82 mid=75 min_val=50 max_val=100
# Загаданное число=82 mid=88 min_val=75 max_val=100
# Загаданное число=82 mid=82 min_val=75 max_val=88
# Загаданное число=51 mid=50 min_val=1 max_val=100
# Загаданное число=51 mid=75 min_val=50 max_val=100
# Загаданное число=51 mid=62 min_val=50 max_val=75
# Загаданное число=51 mid=56 min_val=50 max_val=62
# Загаданное число=51 mid=53 min_val=50 max_val=56
# Загаданное число=51 mid=52 min_val=50 max_val=53
# Загаданное число=51 mid=51 min_val=50 max_val=52
# Загаданное число=84 mid=50 min_val=1 max_val=100
# Загаданное число=84 mid=75 min_val=50 max_val=100
# Загаданное число=84 mid=88 min_val=75 max_val=100
# Загаданное число=84 mid=82 min_val=75 max_val=88
# Загаданное число=84 mid=85 min_val=82 max_val=88
# Загаданное число=84 mid=84 min_val=82 max_val=85
# Загаданное число=68 mid=50 min_val=1 max_val=100
# Загаданное число=68 mid=75 min_val=50 max_val=100
# Загаданное число=68 mid=62 min_val=50 max_val=75
# Загаданное число=68 mid=68 min_val=62 max_val=75
# Загаданное число=38 mid=50 min_val=1 max_val=100
# Загаданное число=38 mid=26 min_val=1 max_val=50
# Загаданное число=38 mid=38 min_val=26 max_val=50
# Загаданное число=17 mid=50 min_val=1 max_val=100
# Загаданное число=17 mid=26 min_val=1 max_val=50
# Загаданное число=17 mid=14 min_val=1 max_val=26
# Загаданное число=17 mid=20 min_val=14 max_val=26
# Загаданное число=17 mid=17 min_val=14 max_val=20
# Загаданное число=88 mid=50 min_val=1 max_val=100
# Загаданное число=88 mid=75 min_val=50 max_val=100
# Загаданное число=88 mid=88 min_val=75 max_val=100
# Загаданное число=56 mid=50 min_val=1 max_val=100
# Загаданное число=56 mid=75 min_val=50 max_val=100
# Загаданное число=56 mid=62 min_val=50 max_val=75
# Загаданное число=56 mid=56 min_val=50 max_val=62
# Загаданное число=59 mid=50 min_val=1 max_val=100
# Загаданное число=59 mid=75 min_val=50 max_val=100
# Загаданное число=59 mid=62 min_val=50 max_val=75
# Загаданное число=59 mid=56 min_val=50 max_val=62
# Загаданное число=59 mid=59 min_val=56 max_val=62
# Загаданное число=16 mid=50 min_val=1 max_val=100
# Загаданное число=16 mid=26 min_val=1 max_val=50
# Загаданное число=16 mid=14 min_val=1 max_val=26
# Загаданное число=16 mid=20 min_val=14 max_val=26
# Загаданное число=16 mid=17 min_val=14 max_val=20
# Загаданное число=16 mid=16 min_val=14 max_val=17
# Загаданное число=67 mid=50 min_val=1 max_val=100
# Загаданное число=67 mid=75 min_val=50 max_val=100
# Загаданное число=67 mid=62 min_val=50 max_val=75
# Загаданное число=67 mid=68 min_val=62 max_val=75
# Загаданное число=67 mid=65 min_val=62 max_val=68
# Загаданное число=67 mid=66 min_val=65 max_val=68
# Загаданное число=67 mid=67 min_val=66 max_val=68
# Загаданное число=2 mid=50 min_val=1 max_val=100
# Загаданное число=2 mid=26 min_val=1 max_val=50
# Загаданное число=2 mid=14 min_val=1 max_val=26
# Загаданное число=2 mid=8 min_val=1 max_val=14
# Загаданное число=2 mid=4 min_val=1 max_val=8
# Загаданное число=2 mid=2 min_val=1 max_val=4
# Загаданное число=25 mid=50 min_val=1 max_val=100
# Загаданное число=25 mid=26 min_val=1 max_val=50
# Загаданное число=25 mid=14 min_val=1 max_val=26
# Загаданное число=25 mid=20 min_val=14 max_val=26
# Загаданное число=25 mid=23 min_val=20 max_val=26
# Загаданное число=25 mid=24 min_val=23 max_val=26
# Загаданное число=25 mid=25 min_val=24 max_val=26
# Загаданное число=21 mid=50 min_val=1 max_val=100
# Загаданное число=21 mid=26 min_val=1 max_val=50
# Загаданное число=21 mid=14 min_val=1 max_val=26
# Загаданное число=21 mid=20 min_val=14 max_val=26
# Загаданное число=21 mid=23 min_val=20 max_val=26
# Загаданное число=21 mid=22 min_val=20 max_val=23
# Загаданное число=21 mid=21 min_val=20 max_val=22
# Загаданное число=42 mid=50 min_val=1 max_val=100
# Загаданное число=42 mid=26 min_val=1 max_val=50
# Загаданное число=42 mid=38 min_val=26 max_val=50
# Загаданное число=42 mid=44 min_val=38 max_val=50
# Загаданное число=42 mid=41 min_val=38 max_val=44
# Загаданное число=42 mid=42 min_val=41 max_val=44
# Загаданное число=45 mid=50 min_val=1 max_val=100
# Загаданное число=45 mid=26 min_val=1 max_val=50
# Загаданное число=45 mid=38 min_val=26 max_val=50
# Загаданное число=45 mid=44 min_val=38 max_val=50
# Загаданное число=45 mid=47 min_val=44 max_val=50
# Загаданное число=45 mid=46 min_val=44 max_val=47
# Загаданное число=45 mid=45 min_val=44 max_val=46
# Загаданное число=7 mid=50 min_val=1 max_val=100
# Загаданное число=7 mid=26 min_val=1 max_val=50
# Загаданное число=7 mid=14 min_val=1 max_val=26
# Загаданное число=7 mid=8 min_val=1 max_val=14
# Загаданное число=7 mid=4 min_val=1 max_val=8
# Загаданное число=7 mid=6 min_val=4 max_val=8
# Загаданное число=7 mid=7 min_val=6 max_val=8
# Загаданное число=44 mid=50 min_val=1 max_val=100
# Загаданное число=44 mid=26 min_val=1 max_val=50
# Загаданное число=44 mid=38 min_val=26 max_val=50
# Загаданное число=44 mid=44 min_val=38 max_val=50
# Загаданное число=22 mid=50 min_val=1 max_val=100
# Загаданное число=22 mid=26 min_val=1 max_val=50
# Загаданное число=22 mid=14 min_val=1 max_val=26
# Загаданное число=22 mid=20 min_val=14 max_val=26
# Загаданное число=22 mid=23 min_val=20 max_val=26
# Загаданное число=22 mid=22 min_val=20 max_val=23
# Загаданное число=2 mid=50 min_val=1 max_val=100
# Загаданное число=2 mid=26 min_val=1 max_val=50
# Загаданное число=2 mid=14 min_val=1 max_val=26
# Загаданное число=2 mid=8 min_val=1 max_val=14
# Загаданное число=2 mid=4 min_val=1 max_val=8
# Загаданное число=2 mid=2 min_val=1 max_val=4
# Загаданное число=20 mid=50 min_val=1 max_val=100
# Загаданное число=20 mid=26 min_val=1 max_val=50
# Загаданное число=20 mid=14 min_val=1 max_val=26
# Загаданное число=20 mid=20 min_val=14 max_val=26
# Загаданное число=62 mid=50 min_val=1 max_val=100
# Загаданное число=62 mid=75 min_val=50 max_val=100
# Загаданное число=62 mid=62 min_val=50 max_val=75
# Загаданное число=64 mid=50 min_val=1 max_val=100
# Загаданное число=64 mid=75 min_val=50 max_val=100
# Загаданное число=64 mid=62 min_val=50 max_val=75
# Загаданное число=64 mid=68 min_val=62 max_val=75
# Загаданное число=64 mid=65 min_val=62 max_val=68
# Загаданное число=64 mid=64 min_val=62 max_val=65
# Загаданное число=49 mid=50 min_val=1 max_val=100
# Загаданное число=49 mid=26 min_val=1 max_val=50
# Загаданное число=49 mid=38 min_val=26 max_val=50
# Загаданное число=49 mid=44 min_val=38 max_val=50
# Загаданное число=49 mid=47 min_val=44 max_val=50
# Загаданное число=49 mid=48 min_val=47 max_val=50
# Загаданное число=49 mid=49 min_val=48 max_val=50
# Загаданное число=29 mid=50 min_val=1 max_val=100
# Загаданное число=29 mid=26 min_val=1 max_val=50
# Загаданное число=29 mid=38 min_val=26 max_val=50
# Загаданное число=29 mid=32 min_val=26 max_val=38
# Загаданное число=29 mid=29 min_val=26 max_val=32
# Загаданное число=71 mid=50 min_val=1 max_val=100
# Загаданное число=71 mid=75 min_val=50 max_val=100
# Загаданное число=71 mid=62 min_val=50 max_val=75
# Загаданное число=71 mid=68 min_val=62 max_val=75
# Загаданное число=71 mid=72 min_val=68 max_val=75
# Загаданное число=71 mid=70 min_val=68 max_val=72
# Загаданное число=71 mid=71 min_val=70 max_val=72
# Загаданное число=3 mid=50 min_val=1 max_val=100
# Загаданное число=3 mid=26 min_val=1 max_val=50
# Загаданное число=3 mid=14 min_val=1 max_val=26
# Загаданное число=3 mid=8 min_val=1 max_val=14
# Загаданное число=3 mid=4 min_val=1 max_val=8
# Загаданное число=3 mid=2 min_val=1 max_val=4
# Загаданное число=3 mid=3 min_val=2 max_val=4
# Загаданное число=77 mid=50 min_val=1 max_val=100
# Загаданное число=77 mid=75 min_val=50 max_val=100
# Загаданное число=77 mid=88 min_val=75 max_val=100
# Загаданное число=77 mid=82 min_val=75 max_val=88
# Загаданное число=77 mid=78 min_val=75 max_val=82
# Загаданное число=77 mid=76 min_val=75 max_val=78
# Загаданное число=77 mid=77 min_val=76 max_val=78
# Загаданное число=3 mid=50 min_val=1 max_val=100
# Загаданное число=3 mid=26 min_val=1 max_val=50
# Загаданное число=3 mid=14 min_val=1 max_val=26
# Загаданное число=3 mid=8 min_val=1 max_val=14
# Загаданное число=3 mid=4 min_val=1 max_val=8
# Загаданное число=3 mid=2 min_val=1 max_val=4
# Загаданное число=3 mid=3 min_val=2 max_val=4
# Загаданное число=25 mid=50 min_val=1 max_val=100
# Загаданное число=25 mid=26 min_val=1 max_val=50
# Загаданное число=25 mid=14 min_val=1 max_val=26
# Загаданное число=25 mid=20 min_val=14 max_val=26
# Загаданное число=25 mid=23 min_val=20 max_val=26
# Загаданное число=25 mid=24 min_val=23 max_val=26
# Загаданное число=25 mid=25 min_val=24 max_val=26
# Загаданное число=53 mid=50 min_val=1 max_val=100
# Загаданное число=53 mid=75 min_val=50 max_val=100
# Загаданное число=53 mid=62 min_val=50 max_val=75
# Загаданное число=53 mid=56 min_val=50 max_val=62
# Загаданное число=53 mid=53 min_val=50 max_val=56
# Загаданное число=57 mid=50 min_val=1 max_val=100
# Загаданное число=57 mid=75 min_val=50 max_val=100
# Загаданное число=57 mid=62 min_val=50 max_val=75
# Загаданное число=57 mid=56 min_val=50 max_val=62
# Загаданное число=57 mid=59 min_val=56 max_val=62
# Загаданное число=57 mid=58 min_val=56 max_val=59
# Загаданное число=57 mid=57 min_val=56 max_val=58
# Загаданное число=25 mid=50 min_val=1 max_val=100
# Загаданное число=25 mid=26 min_val=1 max_val=50
# Загаданное число=25 mid=14 min_val=1 max_val=26
# Загаданное число=25 mid=20 min_val=14 max_val=26
# Загаданное число=25 mid=23 min_val=20 max_val=26
# Загаданное число=25 mid=24 min_val=23 max_val=26
# Загаданное число=25 mid=25 min_val=24 max_val=26
# Загаданное число=86 mid=50 min_val=1 max_val=100
# Загаданное число=86 mid=75 min_val=50 max_val=100
# Загаданное число=86 mid=88 min_val=75 max_val=100
# Загаданное число=86 mid=82 min_val=75 max_val=88
# Загаданное число=86 mid=85 min_val=82 max_val=88
# Загаданное число=86 mid=86 min_val=85 max_val=88
# Загаданное число=77 mid=50 min_val=1 max_val=100
# Загаданное число=77 mid=75 min_val=50 max_val=100
# Загаданное число=77 mid=88 min_val=75 max_val=100
# Загаданное число=77 mid=82 min_val=75 max_val=88
# Загаданное число=77 mid=78 min_val=75 max_val=82
# Загаданное число=77 mid=76 min_val=75 max_val=78
# Загаданное число=77 mid=77 min_val=76 max_val=78
# Загаданное число=11 mid=50 min_val=1 max_val=100
# Загаданное число=11 mid=26 min_val=1 max_val=50
# Загаданное число=11 mid=14 min_val=1 max_val=26
# Загаданное число=11 mid=8 min_val=1 max_val=14
# Загаданное число=11 mid=11 min_val=8 max_val=14
# Загаданное число=92 mid=50 min_val=1 max_val=100
# Загаданное число=92 mid=75 min_val=50 max_val=100
# Загаданное число=92 mid=88 min_val=75 max_val=100
# Загаданное число=92 mid=94 min_val=88 max_val=100
# Загаданное число=92 mid=91 min_val=88 max_val=94
# Загаданное число=92 mid=92 min_val=91 max_val=94
# Загаданное число=31 mid=50 min_val=1 max_val=100
# Загаданное число=31 mid=26 min_val=1 max_val=50
# Загаданное число=31 mid=38 min_val=26 max_val=50
# Загаданное число=31 mid=32 min_val=26 max_val=38
# Загаданное число=31 mid=29 min_val=26 max_val=32
# Загаданное число=31 mid=30 min_val=29 max_val=32
# Загаданное число=31 mid=31 min_val=30 max_val=32
# Загаданное число=82 mid=50 min_val=1 max_val=100
# Загаданное число=82 mid=75 min_val=50 max_val=100
# Загаданное число=82 mid=88 min_val=75 max_val=100
# Загаданное число=82 mid=82 min_val=75 max_val=88
# Загаданное число=71 mid=50 min_val=1 max_val=100
# Загаданное число=71 mid=75 min_val=50 max_val=100
# Загаданное число=71 mid=62 min_val=50 max_val=75
# Загаданное число=71 mid=68 min_val=62 max_val=75
# Загаданное число=71 mid=72 min_val=68 max_val=75
# Загаданное число=71 mid=70 min_val=68 max_val=72
# Загаданное число=71 mid=71 min_val=70 max_val=72
# Загаданное число=64 mid=50 min_val=1 max_val=100
# Загаданное число=64 mid=75 min_val=50 max_val=100
# Загаданное число=64 mid=62 min_val=50 max_val=75
# Загаданное число=64 mid=68 min_val=62 max_val=75
# Загаданное число=64 mid=65 min_val=62 max_val=68
# Загаданное число=64 mid=64 min_val=62 max_val=65
# Загаданное число=53 mid=50 min_val=1 max_val=100
# Загаданное число=53 mid=75 min_val=50 max_val=100
# Загаданное число=53 mid=62 min_val=50 max_val=75
# Загаданное число=53 mid=56 min_val=50 max_val=62
# Загаданное число=53 mid=53 min_val=50 max_val=56
# Загаданное число=73 mid=50 min_val=1 max_val=100
# Загаданное число=73 mid=75 min_val=50 max_val=100
# Загаданное число=73 mid=62 min_val=50 max_val=75
# Загаданное число=73 mid=68 min_val=62 max_val=75
# Загаданное число=73 mid=72 min_val=68 max_val=75
# Загаданное число=73 mid=74 min_val=72 max_val=75
# Загаданное число=73 mid=73 min_val=72 max_val=74
# Загаданное число=55 mid=50 min_val=1 max_val=100
# Загаданное число=55 mid=75 min_val=50 max_val=100
# Загаданное число=55 mid=62 min_val=50 max_val=75
# Загаданное число=55 mid=56 min_val=50 max_val=62
# Загаданное число=55 mid=53 min_val=50 max_val=56
# Загаданное число=55 mid=54 min_val=53 max_val=56
# Загаданное число=55 mid=55 min_val=54 max_val=56
# Загаданное число=90 mid=50 min_val=1 max_val=100
# Загаданное число=90 mid=75 min_val=50 max_val=100
# Загаданное число=90 mid=88 min_val=75 max_val=100
# Загаданное число=90 mid=94 min_val=88 max_val=100
# Загаданное число=90 mid=91 min_val=88 max_val=94
# Загаданное число=90 mid=90 min_val=88 max_val=91
# Загаданное число=43 mid=50 min_val=1 max_val=100
# Загаданное число=43 mid=26 min_val=1 max_val=50
# Загаданное число=43 mid=38 min_val=26 max_val=50
# Загаданное число=43 mid=44 min_val=38 max_val=50
# Загаданное число=43 mid=41 min_val=38 max_val=44
# Загаданное число=43 mid=42 min_val=41 max_val=44
# Загаданное число=43 mid=43 min_val=42 max_val=44
# Загаданное число=72 mid=50 min_val=1 max_val=100
# Загаданное число=72 mid=75 min_val=50 max_val=100
# Загаданное число=72 mid=62 min_val=50 max_val=75
# Загаданное число=72 mid=68 min_val=62 max_val=75
# Загаданное число=72 mid=72 min_val=68 max_val=75
# Загаданное число=65 mid=50 min_val=1 max_val=100
# Загаданное число=65 mid=75 min_val=50 max_val=100
# Загаданное число=65 mid=62 min_val=50 max_val=75
# Загаданное число=65 mid=68 min_val=62 max_val=75
# Загаданное число=65 mid=65 min_val=62 max_val=68
# Загаданное число=84 mid=50 min_val=1 max_val=100
# Загаданное число=84 mid=75 min_val=50 max_val=100
# Загаданное число=84 mid=88 min_val=75 max_val=100
# Загаданное число=84 mid=82 min_val=75 max_val=88
# Загаданное число=84 mid=85 min_val=82 max_val=88
# Загаданное число=84 mid=84 min_val=82 max_val=85
# Загаданное число=60 mid=50 min_val=1 max_val=100
# Загаданное число=60 mid=75 min_val=50 max_val=100
# Загаданное число=60 mid=62 min_val=50 max_val=75
# Загаданное число=60 mid=56 min_val=50 max_val=62
# Загаданное число=60 mid=59 min_val=56 max_val=62
# Загаданное число=60 mid=60 min_val=59 max_val=62
# Загаданное число=80 mid=50 min_val=1 max_val=100
# Загаданное число=80 mid=75 min_val=50 max_val=100
# Загаданное число=80 mid=88 min_val=75 max_val=100
# Загаданное число=80 mid=82 min_val=75 max_val=88
# Загаданное число=80 mid=78 min_val=75 max_val=82
# Загаданное число=80 mid=80 min_val=78 max_val=82
# Загаданное число=30 mid=50 min_val=1 max_val=100
# Загаданное число=30 mid=26 min_val=1 max_val=50
# Загаданное число=30 mid=38 min_val=26 max_val=50
# Загаданное число=30 mid=32 min_val=26 max_val=38
# Загаданное число=30 mid=29 min_val=26 max_val=32
# Загаданное число=30 mid=30 min_val=29 max_val=32
# Загаданное число=9 mid=50 min_val=1 max_val=100
# Загаданное число=9 mid=26 min_val=1 max_val=50
# Загаданное число=9 mid=14 min_val=1 max_val=26
# Загаданное число=9 mid=8 min_val=1 max_val=14
# Загаданное число=9 mid=11 min_val=8 max_val=14
# Загаданное число=9 mid=10 min_val=8 max_val=11
# Загаданное число=9 mid=9 min_val=8 max_val=10
# Загаданное число=56 mid=50 min_val=1 max_val=100
# Загаданное число=56 mid=75 min_val=50 max_val=100
# Загаданное число=56 mid=62 min_val=50 max_val=75
# Загаданное число=56 mid=56 min_val=50 max_val=62
# Загаданное число=55 mid=50 min_val=1 max_val=100
# Загаданное число=55 mid=75 min_val=50 max_val=100
# Загаданное число=55 mid=62 min_val=50 max_val=75
# Загаданное число=55 mid=56 min_val=50 max_val=62
# Загаданное число=55 mid=53 min_val=50 max_val=56
# Загаданное число=55 mid=54 min_val=53 max_val=56
# Загаданное число=55 mid=55 min_val=54 max_val=56
# Загаданное число=72 mid=50 min_val=1 max_val=100
# Загаданное число=72 mid=75 min_val=50 max_val=100
# Загаданное число=72 mid=62 min_val=50 max_val=75
# Загаданное число=72 mid=68 min_val=62 max_val=75
# Загаданное число=72 mid=72 min_val=68 max_val=75
# Загаданное число=21 mid=50 min_val=1 max_val=100
# Загаданное число=21 mid=26 min_val=1 max_val=50
# Загаданное число=21 mid=14 min_val=1 max_val=26
# Загаданное число=21 mid=20 min_val=14 max_val=26
# Загаданное число=21 mid=23 min_val=20 max_val=26
# Загаданное число=21 mid=22 min_val=20 max_val=23
# Загаданное число=21 mid=21 min_val=20 max_val=22
# Загаданное число=88 mid=50 min_val=1 max_val=100
# Загаданное число=88 mid=75 min_val=50 max_val=100
# Загаданное число=88 mid=88 min_val=75 max_val=100
# Загаданное число=69 mid=50 min_val=1 max_val=100
# Загаданное число=69 mid=75 min_val=50 max_val=100
# Загаданное число=69 mid=62 min_val=50 max_val=75
# Загаданное число=69 mid=68 min_val=62 max_val=75
# Загаданное число=69 mid=72 min_val=68 max_val=75
# Загаданное число=69 mid=70 min_val=68 max_val=72
# Загаданное число=69 mid=69 min_val=68 max_val=70
# Загаданное число=38 mid=50 min_val=1 max_val=100
# Загаданное число=38 mid=26 min_val=1 max_val=50
# Загаданное число=38 mid=38 min_val=26 max_val=50
# Загаданное число=70 mid=50 min_val=1 max_val=100
# Загаданное число=70 mid=75 min_val=50 max_val=100
# Загаданное число=70 mid=62 min_val=50 max_val=75
# Загаданное число=70 mid=68 min_val=62 max_val=75
# Загаданное число=70 mid=72 min_val=68 max_val=75
# Загаданное число=70 mid=70 min_val=68 max_val=72
# Загаданное число=84 mid=50 min_val=1 max_val=100
# Загаданное число=84 mid=75 min_val=50 max_val=100
# Загаданное число=84 mid=88 min_val=75 max_val=100
# Загаданное число=84 mid=82 min_val=75 max_val=88
# Загаданное число=84 mid=85 min_val=82 max_val=88
# Загаданное число=84 mid=84 min_val=82 max_val=85
# Загаданное число=65 mid=50 min_val=1 max_val=100
# Загаданное число=65 mid=75 min_val=50 max_val=100
# Загаданное число=65 mid=62 min_val=50 max_val=75
# Загаданное число=65 mid=68 min_val=62 max_val=75
# Загаданное число=65 mid=65 min_val=62 max_val=68
# Загаданное число=28 mid=50 min_val=1 max_val=100
# Загаданное число=28 mid=26 min_val=1 max_val=50
# Загаданное число=28 mid=38 min_val=26 max_val=50
# Загаданное число=28 mid=32 min_val=26 max_val=38
# Загаданное число=28 mid=29 min_val=26 max_val=32
# Загаданное число=28 mid=28 min_val=26 max_val=29
# Загаданное число=91 mid=50 min_val=1 max_val=100
# Загаданное число=91 mid=75 min_val=50 max_val=100
# Загаданное число=91 mid=88 min_val=75 max_val=100
# Загаданное число=91 mid=94 min_val=88 max_val=100
# Загаданное число=91 mid=91 min_val=88 max_val=94
# Загаданное число=9 mid=50 min_val=1 max_val=100
# Загаданное число=9 mid=26 min_val=1 max_val=50
# Загаданное число=9 mid=14 min_val=1 max_val=26
# Загаданное число=9 mid=8 min_val=1 max_val=14
# Загаданное число=9 mid=11 min_val=8 max_val=14
# Загаданное число=9 mid=10 min_val=8 max_val=11
# Загаданное число=9 mid=9 min_val=8 max_val=10
# Загаданное число=88 mid=50 min_val=1 max_val=100
# Загаданное число=88 mid=75 min_val=50 max_val=100
# Загаданное число=88 mid=88 min_val=75 max_val=100
# Загаданное число=88 mid=50 min_val=1 max_val=100
# Загаданное число=88 mid=75 min_val=50 max_val=100
# Загаданное число=88 mid=88 min_val=75 max_val=100
# Загаданное число=9 mid=50 min_val=1 max_val=100
# Загаданное число=9 mid=26 min_val=1 max_val=50
# Загаданное число=9 mid=14 min_val=1 max_val=26
# Загаданное число=9 mid=8 min_val=1 max_val=14
# Загаданное число=9 mid=11 min_val=8 max_val=14
# Загаданное число=9 mid=10 min_val=8 max_val=11
# Загаданное число=9 mid=9 min_val=8 max_val=10
# Загаданное число=47 mid=50 min_val=1 max_val=100
# Загаданное число=47 mid=26 min_val=1 max_val=50
# Загаданное число=47 mid=38 min_val=26 max_val=50
# Загаданное число=47 mid=44 min_val=38 max_val=50
# Загаданное число=47 mid=47 min_val=44 max_val=50
# Загаданное число=15 mid=50 min_val=1 max_val=100
# Загаданное число=15 mid=26 min_val=1 max_val=50
# Загаданное число=15 mid=14 min_val=1 max_val=26
# Загаданное число=15 mid=20 min_val=14 max_val=26
# Загаданное число=15 mid=17 min_val=14 max_val=20
# Загаданное число=15 mid=16 min_val=14 max_val=17
# Загаданное число=15 mid=15 min_val=14 max_val=16
# Загаданное число=53 mid=50 min_val=1 max_val=100
# Загаданное число=53 mid=75 min_val=50 max_val=100
# Загаданное число=53 mid=62 min_val=50 max_val=75
# Загаданное число=53 mid=56 min_val=50 max_val=62
# Загаданное число=53 mid=53 min_val=50 max_val=56
# Загаданное число=63 mid=50 min_val=1 max_val=100
# Загаданное число=63 mid=75 min_val=50 max_val=100
# Загаданное число=63 mid=62 min_val=50 max_val=75
# Загаданное число=63 mid=68 min_val=62 max_val=75
# Загаданное число=63 mid=65 min_val=62 max_val=68
# Загаданное число=63 mid=64 min_val=62 max_val=65
# Загаданное число=63 mid=63 min_val=62 max_val=64
# Загаданное число=66 mid=50 min_val=1 max_val=100
# Загаданное число=66 mid=75 min_val=50 max_val=100
# Загаданное число=66 mid=62 min_val=50 max_val=75
# Загаданное число=66 mid=68 min_val=62 max_val=75
# Загаданное число=66 mid=65 min_val=62 max_val=68
# Загаданное число=66 mid=66 min_val=65 max_val=68
# Загаданное число=47 mid=50 min_val=1 max_val=100
# Загаданное число=47 mid=26 min_val=1 max_val=50
# Загаданное число=47 mid=38 min_val=26 max_val=50
# Загаданное число=47 mid=44 min_val=38 max_val=50
# Загаданное число=47 mid=47 min_val=44 max_val=50
# Загаданное число=50 mid=50 min_val=1 max_val=100
# Загаданное число=99 mid=50 min_val=1 max_val=100
# Загаданное число=99 mid=75 min_val=50 max_val=100
# Загаданное число=99 mid=88 min_val=75 max_val=100
# Загаданное число=99 mid=94 min_val=88 max_val=100
# Загаданное число=99 mid=97 min_val=94 max_val=100
# Загаданное число=99 mid=98 min_val=97 max_val=100
# Загаданное число=99 mid=99 min_val=98 max_val=100
# Загаданное число=83 mid=50 min_val=1 max_val=100
# Загаданное число=83 mid=75 min_val=50 max_val=100
# Загаданное число=83 mid=88 min_val=75 max_val=100
# Загаданное число=83 mid=82 min_val=75 max_val=88
# Загаданное число=83 mid=85 min_val=82 max_val=88
# Загаданное число=83 mid=84 min_val=82 max_val=85
# Загаданное число=83 mid=83 min_val=82 max_val=84
# Загаданное число=72 mid=50 min_val=1 max_val=100
# Загаданное число=72 mid=75 min_val=50 max_val=100
# Загаданное число=72 mid=62 min_val=50 max_val=75
# Загаданное число=72 mid=68 min_val=62 max_val=75
# Загаданное число=72 mid=72 min_val=68 max_val=75
# Загаданное число=62 mid=50 min_val=1 max_val=100
# Загаданное число=62 mid=75 min_val=50 max_val=100
# Загаданное число=62 mid=62 min_val=50 max_val=75
# Загаданное число=47 mid=50 min_val=1 max_val=100
# Загаданное число=47 mid=26 min_val=1 max_val=50
# Загаданное число=47 mid=38 min_val=26 max_val=50
# Загаданное число=47 mid=44 min_val=38 max_val=50
# Загаданное число=47 mid=47 min_val=44 max_val=50
# Загаданное число=60 mid=50 min_val=1 max_val=100
# Загаданное число=60 mid=75 min_val=50 max_val=100
# Загаданное число=60 mid=62 min_val=50 max_val=75
# Загаданное число=60 mid=56 min_val=50 max_val=62
# Загаданное число=60 mid=59 min_val=56 max_val=62
# Загаданное число=60 mid=60 min_val=59 max_val=62
# Загаданное число=46 mid=50 min_val=1 max_val=100
# Загаданное число=46 mid=26 min_val=1 max_val=50
# Загаданное число=46 mid=38 min_val=26 max_val=50
# Загаданное число=46 mid=44 min_val=38 max_val=50
# Загаданное число=46 mid=47 min_val=44 max_val=50
# Загаданное число=46 mid=46 min_val=44 max_val=47
# Загаданное число=18 mid=50 min_val=1 max_val=100
# Загаданное число=18 mid=26 min_val=1 max_val=50
# Загаданное число=18 mid=14 min_val=1 max_val=26
# Загаданное число=18 mid=20 min_val=14 max_val=26
# Загаданное число=18 mid=17 min_val=14 max_val=20
# Загаданное число=18 mid=18 min_val=17 max_val=20
# Загаданное число=28 mid=50 min_val=1 max_val=100
# Загаданное число=28 mid=26 min_val=1 max_val=50
# Загаданное число=28 mid=38 min_val=26 max_val=50
# Загаданное число=28 mid=32 min_val=26 max_val=38
# Загаданное число=28 mid=29 min_val=26 max_val=32
# Загаданное число=28 mid=28 min_val=26 max_val=29
# Загаданное число=31 mid=50 min_val=1 max_val=100
# Загаданное число=31 mid=26 min_val=1 max_val=50
# Загаданное число=31 mid=38 min_val=26 max_val=50
# Загаданное число=31 mid=32 min_val=26 max_val=38
# Загаданное число=31 mid=29 min_val=26 max_val=32
# Загаданное число=31 mid=30 min_val=29 max_val=32
# Загаданное число=31 mid=31 min_val=30 max_val=32
# Загаданное число=53 mid=50 min_val=1 max_val=100
# Загаданное число=53 mid=75 min_val=50 max_val=100
# Загаданное число=53 mid=62 min_val=50 max_val=75
# Загаданное число=53 mid=56 min_val=50 max_val=62
# Загаданное число=53 mid=53 min_val=50 max_val=56
# Загаданное число=95 mid=50 min_val=1 max_val=100
# Загаданное число=95 mid=75 min_val=50 max_val=100
# Загаданное число=95 mid=88 min_val=75 max_val=100
# Загаданное число=95 mid=94 min_val=88 max_val=100
# Загаданное число=95 mid=97 min_val=94 max_val=100
# Загаданное число=95 mid=96 min_val=94 max_val=97
# Загаданное число=95 mid=95 min_val=94 max_val=96
# Загаданное число=77 mid=50 min_val=1 max_val=100
# Загаданное число=77 mid=75 min_val=50 max_val=100
# Загаданное число=77 mid=88 min_val=75 max_val=100
# Загаданное число=77 mid=82 min_val=75 max_val=88
# Загаданное число=77 mid=78 min_val=75 max_val=82
# Загаданное число=77 mid=76 min_val=75 max_val=78
# Загаданное число=77 mid=77 min_val=76 max_val=78
# Загаданное число=41 mid=50 min_val=1 max_val=100
# Загаданное число=41 mid=26 min_val=1 max_val=50
# Загаданное число=41 mid=38 min_val=26 max_val=50
# Загаданное число=41 mid=44 min_val=38 max_val=50
# Загаданное число=41 mid=41 min_val=38 max_val=44
# Загаданное число=4 mid=50 min_val=1 max_val=100
# Загаданное число=4 mid=26 min_val=1 max_val=50
# Загаданное число=4 mid=14 min_val=1 max_val=26
# Загаданное число=4 mid=8 min_val=1 max_val=14
# Загаданное число=4 mid=4 min_val=1 max_val=8
# Загаданное число=33 mid=50 min_val=1 max_val=100
# Загаданное число=33 mid=26 min_val=1 max_val=50
# Загаданное число=33 mid=38 min_val=26 max_val=50
# Загаданное число=33 mid=32 min_val=26 max_val=38
# Загаданное число=33 mid=35 min_val=32 max_val=38
# Загаданное число=33 mid=34 min_val=32 max_val=35
# Загаданное число=33 mid=33 min_val=32 max_val=34
# Загаданное число=69 mid=50 min_val=1 max_val=100
# Загаданное число=69 mid=75 min_val=50 max_val=100
# Загаданное число=69 mid=62 min_val=50 max_val=75
# Загаданное число=69 mid=68 min_val=62 max_val=75
# Загаданное число=69 mid=72 min_val=68 max_val=75
# Загаданное число=69 mid=70 min_val=68 max_val=72
# Загаданное число=69 mid=69 min_val=68 max_val=70
# Загаданное число=91 mid=50 min_val=1 max_val=100
# Загаданное число=91 mid=75 min_val=50 max_val=100
# Загаданное число=91 mid=88 min_val=75 max_val=100
# Загаданное число=91 mid=94 min_val=88 max_val=100
# Загаданное число=91 mid=91 min_val=88 max_val=94
# Загаданное число=47 mid=50 min_val=1 max_val=100
# Загаданное число=47 mid=26 min_val=1 max_val=50
# Загаданное число=47 mid=38 min_val=26 max_val=50
# Загаданное число=47 mid=44 min_val=38 max_val=50
# Загаданное число=47 mid=47 min_val=44 max_val=50
# Загаданное число=15 mid=50 min_val=1 max_val=100
# Загаданное число=15 mid=26 min_val=1 max_val=50
# Загаданное число=15 mid=14 min_val=1 max_val=26
# Загаданное число=15 mid=20 min_val=14 max_val=26
# Загаданное число=15 mid=17 min_val=14 max_val=20
# Загаданное число=15 mid=16 min_val=14 max_val=17
# Загаданное число=15 mid=15 min_val=14 max_val=16
# Загаданное число=63 mid=50 min_val=1 max_val=100
# Загаданное число=63 mid=75 min_val=50 max_val=100
# Загаданное число=63 mid=62 min_val=50 max_val=75
# Загаданное число=63 mid=68 min_val=62 max_val=75
# Загаданное число=63 mid=65 min_val=62 max_val=68
# Загаданное число=63 mid=64 min_val=62 max_val=65
# Загаданное число=63 mid=63 min_val=62 max_val=64
# Загаданное число=13 mid=50 min_val=1 max_val=100
# Загаданное число=13 mid=26 min_val=1 max_val=50
# Загаданное число=13 mid=14 min_val=1 max_val=26
# Загаданное число=13 mid=8 min_val=1 max_val=14
# Загаданное число=13 mid=11 min_val=8 max_val=14
# Загаданное число=13 mid=12 min_val=11 max_val=14
# Загаданное число=13 mid=13 min_val=12 max_val=14
# Загаданное число=7 mid=50 min_val=1 max_val=100
# ...
# Загаданное число=26 mid=26 min_val=1 max_val=50
# Загаданное число=43 mid=50 min_val=1 max_val=100
# Загаданное число=43 mid=26 min_val=1 max_val=50
# Загаданное число=43 mid=38 min_val=26 max_val=50
# Загаданное число=43 mid=44 min_val=38 max_val=50
# Загаданное число=43 mid=41 min_val=38 max_val=44
# Загаданное число=43 mid=42 min_val=41 max_val=44
# Загаданное число=43 mid=43 min_val=42 max_val=44
# Загаданное число=90 mid=50 min_val=1 max_val=100
# Загаданное число=90 mid=75 min_val=50 max_val=100
# Загаданное число=90 mid=88 min_val=75 max_val=100
# Загаданное число=90 mid=94 min_val=88 max_val=100
# Загаданное число=90 mid=91 min_val=88 max_val=94
# Загаданное число=90 mid=90 min_val=88 max_val=91
# Загаданное число=41 mid=50 min_val=1 max_val=100
# Загаданное число=41 mid=26 min_val=1 max_val=50
# Загаданное число=41 mid=38 min_val=26 max_val=50
# Загаданное число=41 mid=44 min_val=38 max_val=50
# Загаданное число=41 mid=41 min_val=38 max_val=44
# Загаданное число=52 mid=50 min_val=1 max_val=100
# Загаданное число=52 mid=75 min_val=50 max_val=100
# Загаданное число=52 mid=62 min_val=50 max_val=75
# Загаданное число=52 mid=56 min_val=50 max_val=62
# Загаданное число=52 mid=53 min_val=50 max_val=56
# Загаданное число=52 mid=52 min_val=50 max_val=53
# Загаданное число=94 mid=50 min_val=1 max_val=100
# Загаданное число=94 mid=75 min_val=50 max_val=100
# Загаданное число=94 mid=88 min_val=75 max_val=100
# Загаданное число=94 mid=94 min_val=88 max_val=100
# Загаданное число=17 mid=50 min_val=1 max_val=100
# Загаданное число=17 mid=26 min_val=1 max_val=50
# Загаданное число=17 mid=14 min_val=1 max_val=26
# Загаданное число=17 mid=20 min_val=14 max_val=26
# Загаданное число=17 mid=17 min_val=14 max_val=20
# Загаданное число=30 mid=50 min_val=1 max_val=100
# Загаданное число=30 mid=26 min_val=1 max_val=50
# Загаданное число=30 mid=38 min_val=26 max_val=50
# Загаданное число=30 mid=32 min_val=26 max_val=38
# Загаданное число=30 mid=29 min_val=26 max_val=32
# Загаданное число=30 mid=30 min_val=29 max_val=32
# Загаданное число=85 mid=50 min_val=1 max_val=100
# Загаданное число=85 mid=75 min_val=50 max_val=100
# Загаданное число=85 mid=88 min_val=75 max_val=100
# Загаданное число=85 mid=82 min_val=75 max_val=88
# Загаданное число=85 mid=85 min_val=82 max_val=88
# Загаданное число=94 mid=50 min_val=1 max_val=100
# Загаданное число=94 mid=75 min_val=50 max_val=100
# Загаданное число=94 mid=88 min_val=75 max_val=100
# Загаданное число=94 mid=94 min_val=88 max_val=100
# Загаданное число=96 mid=50 min_val=1 max_val=100
# Загаданное число=96 mid=75 min_val=50 max_val=100
# Загаданное число=96 mid=88 min_val=75 max_val=100
# Загаданное число=96 mid=94 min_val=88 max_val=100
# Загаданное число=96 mid=97 min_val=94 max_val=100
# Загаданное число=96 mid=96 min_val=94 max_val=97
# Загаданное число=64 mid=50 min_val=1 max_val=100
# Загаданное число=64 mid=75 min_val=50 max_val=100
# Загаданное число=64 mid=62 min_val=50 max_val=75
# Загаданное число=64 mid=68 min_val=62 max_val=75
# Загаданное число=64 mid=65 min_val=62 max_val=68
# Загаданное число=64 mid=64 min_val=62 max_val=65
# Загаданное число=42 mid=50 min_val=1 max_val=100
# Загаданное число=42 mid=26 min_val=1 max_val=50
# Загаданное число=42 mid=38 min_val=26 max_val=50
# Загаданное число=42 mid=44 min_val=38 max_val=50
# Загаданное число=42 mid=41 min_val=38 max_val=44
# Загаданное число=42 mid=42 min_val=41 max_val=44
# Загаданное число=45 mid=50 min_val=1 max_val=100
# Загаданное число=45 mid=26 min_val=1 max_val=50
# Загаданное число=45 mid=38 min_val=26 max_val=50
# Загаданное число=45 mid=44 min_val=38 max_val=50
# Загаданное число=45 mid=47 min_val=44 max_val=50
# Загаданное число=45 mid=46 min_val=44 max_val=47
# Загаданное число=45 mid=45 min_val=44 max_val=46
# Загаданное число=67 mid=50 min_val=1 max_val=100
# Загаданное число=67 mid=75 min_val=50 max_val=100
# Загаданное число=67 mid=62 min_val=50 max_val=75
# Загаданное число=67 mid=68 min_val=62 max_val=75
# Загаданное число=67 mid=65 min_val=62 max_val=68
# Загаданное число=67 mid=66 min_val=65 max_val=68
# Загаданное число=67 mid=67 min_val=66 max_val=68
# Загаданное число=13 mid=50 min_val=1 max_val=100
# Загаданное число=13 mid=26 min_val=1 max_val=50
# Загаданное число=13 mid=14 min_val=1 max_val=26
# Загаданное число=13 mid=8 min_val=1 max_val=14
# Загаданное число=13 mid=11 min_val=8 max_val=14
# Загаданное число=13 mid=12 min_val=11 max_val=14
# Загаданное число=13 mid=13 min_val=12 max_val=14
# Загаданное число=99 mid=50 min_val=1 max_val=100
# Загаданное число=99 mid=75 min_val=50 max_val=100
# Загаданное число=99 mid=88 min_val=75 max_val=100
# Загаданное число=99 mid=94 min_val=88 max_val=100
# Загаданное число=99 mid=97 min_val=94 max_val=100
# Загаданное число=99 mid=98 min_val=97 max_val=100
# Загаданное число=99 mid=99 min_val=98 max_val=100
# Загаданное число=53 mid=50 min_val=1 max_val=100
# Загаданное число=53 mid=75 min_val=50 max_val=100
# Загаданное число=53 mid=62 min_val=50 max_val=75
# Загаданное число=53 mid=56 min_val=50 max_val=62
# Загаданное число=53 mid=53 min_val=50 max_val=56
# Загаданное число=97 mid=50 min_val=1 max_val=100
# Загаданное число=97 mid=75 min_val=50 max_val=100
# Загаданное число=97 mid=88 min_val=75 max_val=100
# Загаданное число=97 mid=94 min_val=88 max_val=100
# Загаданное число=97 mid=97 min_val=94 max_val=100
# Загаданное число=92 mid=50 min_val=1 max_val=100
# Загаданное число=92 mid=75 min_val=50 max_val=100
# Загаданное число=92 mid=88 min_val=75 max_val=100
# Загаданное число=92 mid=94 min_val=88 max_val=100
# Загаданное число=92 mid=91 min_val=88 max_val=94
# Загаданное число=92 mid=92 min_val=91 max_val=94
# Загаданное число=67 mid=50 min_val=1 max_val=100
# Загаданное число=67 mid=75 min_val=50 max_val=100
# Загаданное число=67 mid=62 min_val=50 max_val=75
# Загаданное число=67 mid=68 min_val=62 max_val=75
# Загаданное число=67 mid=65 min_val=62 max_val=68
# Загаданное число=67 mid=66 min_val=65 max_val=68
# Загаданное число=67 mid=67 min_val=66 max_val=68
# Загаданное число=80 mid=50 min_val=1 max_val=100
# Загаданное число=80 mid=75 min_val=50 max_val=100
# Загаданное число=80 mid=88 min_val=75 max_val=100
# Загаданное число=80 mid=82 min_val=75 max_val=88
# Загаданное число=80 mid=78 min_val=75 max_val=82
# Загаданное число=80 mid=80 min_val=78 max_val=82
# Загаданное число=90 mid=50 min_val=1 max_val=100
# Загаданное число=90 mid=75 min_val=50 max_val=100
# Загаданное число=90 mid=88 min_val=75 max_val=100
# Загаданное число=90 mid=94 min_val=88 max_val=100
# Загаданное число=90 mid=91 min_val=88 max_val=94
# Загаданное число=90 mid=90 min_val=88 max_val=91
# Загаданное число=44 mid=50 min_val=1 max_val=100
# Загаданное число=44 mid=26 min_val=1 max_val=50
# Загаданное число=44 mid=38 min_val=26 max_val=50
# Загаданное число=44 mid=44 min_val=38 max_val=50
# Загаданное число=33 mid=50 min_val=1 max_val=100
# Загаданное число=33 mid=26 min_val=1 max_val=50
# Загаданное число=33 mid=38 min_val=26 max_val=50
# Загаданное число=33 mid=32 min_val=26 max_val=38
# Загаданное число=33 mid=35 min_val=32 max_val=38
# Загаданное число=33 mid=34 min_val=32 max_val=35
# Загаданное число=33 mid=33 min_val=32 max_val=34
# Загаданное число=62 mid=50 min_val=1 max_val=100
# Загаданное число=62 mid=75 min_val=50 max_val=100
# Загаданное число=62 mid=62 min_val=50 max_val=75
# Загаданное число=85 mid=50 min_val=1 max_val=100
# Загаданное число=85 mid=75 min_val=50 max_val=100
# Загаданное число=85 mid=88 min_val=75 max_val=100
# Загаданное число=85 mid=82 min_val=75 max_val=88
# Загаданное число=85 mid=85 min_val=82 max_val=88
# Загаданное число=32 mid=50 min_val=1 max_val=100
# Загаданное число=32 mid=26 min_val=1 max_val=50
# Загаданное число=32 mid=38 min_val=26 max_val=50
# Загаданное число=32 mid=32 min_val=26 max_val=38
# Загаданное число=57 mid=50 min_val=1 max_val=100
# Загаданное число=57 mid=75 min_val=50 max_val=100
# Загаданное число=57 mid=62 min_val=50 max_val=75
# Загаданное число=57 mid=56 min_val=50 max_val=62
# Загаданное число=57 mid=59 min_val=56 max_val=62
# Загаданное число=57 mid=58 min_val=56 max_val=59
# Загаданное число=57 mid=57 min_val=56 max_val=58
# Загаданное число=24 mid=50 min_val=1 max_val=100
# Загаданное число=24 mid=26 min_val=1 max_val=50
# Загаданное число=24 mid=14 min_val=1 max_val=26
# Загаданное число=24 mid=20 min_val=14 max_val=26
# Загаданное число=24 mid=23 min_val=20 max_val=26
# Загаданное число=24 mid=24 min_val=23 max_val=26
# Загаданное число=22 mid=50 min_val=1 max_val=100
# Загаданное число=22 mid=26 min_val=1 max_val=50
# Загаданное число=22 mid=14 min_val=1 max_val=26
# Загаданное число=22 mid=20 min_val=14 max_val=26
# Загаданное число=22 mid=23 min_val=20 max_val=26
# Загаданное число=22 mid=22 min_val=20 max_val=23
# Загаданное число=2 mid=50 min_val=1 max_val=100
# Загаданное число=2 mid=26 min_val=1 max_val=50
# Загаданное число=2 mid=14 min_val=1 max_val=26
# Загаданное число=2 mid=8 min_val=1 max_val=14
# Загаданное число=2 mid=4 min_val=1 max_val=8
# Загаданное число=2 mid=2 min_val=1 max_val=4
# Загаданное число=57 mid=50 min_val=1 max_val=100
# Загаданное число=57 mid=75 min_val=50 max_val=100
# Загаданное число=57 mid=62 min_val=50 max_val=75
# Загаданное число=57 mid=56 min_val=50 max_val=62
# Загаданное число=57 mid=59 min_val=56 max_val=62
# Загаданное число=57 mid=58 min_val=56 max_val=59
# Загаданное число=57 mid=57 min_val=56 max_val=58
# Загаданное число=30 mid=50 min_val=1 max_val=100
# Загаданное число=30 mid=26 min_val=1 max_val=50
# Загаданное число=30 mid=38 min_val=26 max_val=50
# Загаданное число=30 mid=32 min_val=26 max_val=38
# Загаданное число=30 mid=29 min_val=26 max_val=32
# Загаданное число=30 mid=30 min_val=29 max_val=32
# Загаданное число=31 mid=50 min_val=1 max_val=100
# Загаданное число=31 mid=26 min_val=1 max_val=50
# Загаданное число=31 mid=38 min_val=26 max_val=50
# Загаданное число=31 mid=32 min_val=26 max_val=38
# Загаданное число=31 mid=29 min_val=26 max_val=32
# Загаданное число=31 mid=30 min_val=29 max_val=32
# Загаданное число=31 mid=31 min_val=30 max_val=32
# Загаданное число=28 mid=50 min_val=1 max_val=100
# Загаданное число=28 mid=26 min_val=1 max_val=50
# Загаданное число=28 mid=38 min_val=26 max_val=50
# Загаданное число=28 mid=32 min_val=26 max_val=38
# Загаданное число=28 mid=29 min_val=26 max_val=32
# Загаданное число=28 mid=28 min_val=26 max_val=29
# Загаданное число=73 mid=50 min_val=1 max_val=100
# Загаданное число=73 mid=75 min_val=50 max_val=100
# Загаданное число=73 mid=62 min_val=50 max_val=75
# Загаданное число=73 mid=68 min_val=62 max_val=75
# Загаданное число=73 mid=72 min_val=68 max_val=75
# Загаданное число=73 mid=74 min_val=72 max_val=75
# Загаданное число=73 mid=73 min_val=72 max_val=74
# Загаданное число=81 mid=50 min_val=1 max_val=100
# Загаданное число=81 mid=75 min_val=50 max_val=100
# Загаданное число=81 mid=88 min_val=75 max_val=100
# Загаданное число=81 mid=82 min_val=75 max_val=88
# Загаданное число=81 mid=78 min_val=75 max_val=82
# Загаданное число=81 mid=80 min_val=78 max_val=82
# Загаданное число=81 mid=81 min_val=80 max_val=82
# Загаданное число=7 mid=50 min_val=1 max_val=100
# Загаданное число=7 mid=26 min_val=1 max_val=50
# Загаданное число=7 mid=14 min_val=1 max_val=26
# Загаданное число=7 mid=8 min_val=1 max_val=14
# Загаданное число=7 mid=4 min_val=1 max_val=8
# Загаданное число=7 mid=6 min_val=4 max_val=8
# Загаданное число=7 mid=7 min_val=6 max_val=8
# Загаданное число=34 mid=50 min_val=1 max_val=100
# Загаданное число=34 mid=26 min_val=1 max_val=50
# Загаданное число=34 mid=38 min_val=26 max_val=50
# Загаданное число=34 mid=32 min_val=26 max_val=38
# Загаданное число=34 mid=35 min_val=32 max_val=38
# Загаданное число=34 mid=34 min_val=32 max_val=35
# Загаданное число=49 mid=50 min_val=1 max_val=100
# Загаданное число=49 mid=26 min_val=1 max_val=50
# Загаданное число=49 mid=38 min_val=26 max_val=50
# Загаданное число=49 mid=44 min_val=38 max_val=50
# Загаданное число=49 mid=47 min_val=44 max_val=50
# Загаданное число=49 mid=48 min_val=47 max_val=50
# Загаданное число=49 mid=49 min_val=48 max_val=50
# Загаданное число=92 mid=50 min_val=1 max_val=100
# Загаданное число=92 mid=75 min_val=50 max_val=100
# Загаданное число=92 mid=88 min_val=75 max_val=100
# Загаданное число=92 mid=94 min_val=88 max_val=100
# Загаданное число=92 mid=91 min_val=88 max_val=94
# Загаданное число=92 mid=92 min_val=91 max_val=94
# Загаданное число=12 mid=50 min_val=1 max_val=100
# Загаданное число=12 mid=26 min_val=1 max_val=50
# Загаданное число=12 mid=14 min_val=1 max_val=26
# Загаданное число=12 mid=8 min_val=1 max_val=14
# Загаданное число=12 mid=11 min_val=8 max_val=14
# Загаданное число=12 mid=12 min_val=11 max_val=14
# Загаданное число=82 mid=50 min_val=1 max_val=100
# Загаданное число=82 mid=75 min_val=50 max_val=100
# Загаданное число=82 mid=88 min_val=75 max_val=100
# Загаданное число=82 mid=82 min_val=75 max_val=88
# Загаданное число=12 mid=50 min_val=1 max_val=100
# Загаданное число=12 mid=26 min_val=1 max_val=50
# Загаданное число=12 mid=14 min_val=1 max_val=26
# Загаданное число=12 mid=8 min_val=1 max_val=14
# Загаданное число=12 mid=11 min_val=8 max_val=14
# Загаданное число=12 mid=12 min_val=11 max_val=14
# Загаданное число=25 mid=50 min_val=1 max_val=100
# Загаданное число=25 mid=26 min_val=1 max_val=50
# Загаданное число=25 mid=14 min_val=1 max_val=26
# Загаданное число=25 mid=20 min_val=14 max_val=26
# Загаданное число=25 mid=23 min_val=20 max_val=26
# Загаданное число=25 mid=24 min_val=23 max_val=26
# Загаданное число=25 mid=25 min_val=24 max_val=26
# Загаданное число=31 mid=50 min_val=1 max_val=100
# Загаданное число=31 mid=26 min_val=1 max_val=50
# Загаданное число=31 mid=38 min_val=26 max_val=50
# Загаданное число=31 mid=32 min_val=26 max_val=38
# Загаданное число=31 mid=29 min_val=26 max_val=32
# Загаданное число=31 mid=30 min_val=29 max_val=32
# Загаданное число=31 mid=31 min_val=30 max_val=32
# Загаданное число=19 mid=50 min_val=1 max_val=100
# Загаданное число=19 mid=26 min_val=1 max_val=50
# Загаданное число=19 mid=14 min_val=1 max_val=26
# Загаданное число=19 mid=20 min_val=14 max_val=26
# Загаданное число=19 mid=17 min_val=14 max_val=20
# Загаданное число=19 mid=18 min_val=17 max_val=20
# Загаданное число=19 mid=19 min_val=18 max_val=20
# Загаданное число=5 mid=50 min_val=1 max_val=100
# Загаданное число=5 mid=26 min_val=1 max_val=50
# Загаданное число=5 mid=14 min_val=1 max_val=26
# Загаданное число=5 mid=8 min_val=1 max_val=14
# Загаданное число=5 mid=4 min_val=1 max_val=8
# Загаданное число=5 mid=6 min_val=4 max_val=8
# Загаданное число=5 mid=5 min_val=4 max_val=6
# Загаданное число=41 mid=50 min_val=1 max_val=100
# Загаданное число=41 mid=26 min_val=1 max_val=50
# Загаданное число=41 mid=38 min_val=26 max_val=50
# Загаданное число=41 mid=44 min_val=38 max_val=50
# Загаданное число=41 mid=41 min_val=38 max_val=44
# Загаданное число=75 mid=50 min_val=1 max_val=100
# Загаданное число=75 mid=75 min_val=50 max_val=100
# Загаданное число=35 mid=50 min_val=1 max_val=100
# Загаданное число=35 mid=26 min_val=1 max_val=50
# Загаданное число=35 mid=38 min_val=26 max_val=50
# Загаданное число=35 mid=32 min_val=26 max_val=38
# Загаданное число=35 mid=35 min_val=32 max_val=38
# Загаданное число=69 mid=50 min_val=1 max_val=100
# Загаданное число=69 mid=75 min_val=50 max_val=100
# Загаданное число=69 mid=62 min_val=50 max_val=75
# Загаданное число=69 mid=68 min_val=62 max_val=75
# Загаданное число=69 mid=72 min_val=68 max_val=75
# Загаданное число=69 mid=70 min_val=68 max_val=72
# Загаданное число=69 mid=69 min_val=68 max_val=70
# Загаданное число=46 mid=50 min_val=1 max_val=100
# Загаданное число=46 mid=26 min_val=1 max_val=50
# Загаданное число=46 mid=38 min_val=26 max_val=50
# Загаданное число=46 mid=44 min_val=38 max_val=50
# Загаданное число=46 mid=47 min_val=44 max_val=50
# Загаданное число=46 mid=46 min_val=44 max_val=47
# Загаданное число=58 mid=50 min_val=1 max_val=100
# Загаданное число=58 mid=75 min_val=50 max_val=100
# Загаданное число=58 mid=62 min_val=50 max_val=75
# Загаданное число=58 mid=56 min_val=50 max_val=62
# Загаданное число=58 mid=59 min_val=56 max_val=62
# Загаданное число=58 mid=58 min_val=56 max_val=59
# Загаданное число=73 mid=50 min_val=1 max_val=100
# Загаданное число=73 mid=75 min_val=50 max_val=100
# Загаданное число=73 mid=62 min_val=50 max_val=75
# Загаданное число=73 mid=68 min_val=62 max_val=75
# Загаданное число=73 mid=72 min_val=68 max_val=75
# Загаданное число=73 mid=74 min_val=72 max_val=75
# Загаданное число=73 mid=73 min_val=72 max_val=74
# Алгоритм угадывает число в среднем за: 5 попыток
